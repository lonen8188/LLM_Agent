# %%
from openai import OpenAI
from dotenv import load_dotenv
import os

load_dotenv()
api_key = os.getenv("OPENAI_API_KEY")  # 환경 변수에서 API 키를 가져옵니다.
client = OpenAI(api_key=api_key)  # OpenAI 클라이언트의 인스턴스를 생성합니다.

# %%
response = client.audio.speech.create(
    model="tts-1-hd",
    voice="alloy",
    input="Hello world! This is a TTS test.",
)

response.write_to_file("hello_world.mp3")

# 재생
import IPython.display as ipd

ipd.Audio("hello_world.mp3")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# 다른 목소리
voice = "ash"
mp3_file = f"hello_world_{voice}.mp3"

response = client.audio.speech.create(
    model="tts-1-hd",
    voice=voice,
    input=f"Hello world! I'm {voice}. This is a TTS test.",
)

response.write_to_file(mp3_file)

# 재생
import IPython.display as ipd

ipd.Audio(mp3_file)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import json

# json 파일 열기
with open('../data/images/image_quiz_eng.json', 'r', encoding='utf-8') as f:
    eng_dict = json.load(f)

eng_dict
# Out:
# [{'no': 1,
#   'eng': 'Which of the following descriptions of the image is incorrect?\n- (1) Many people are using laptops in a conference space.\n- (2) There are several lights installed on the ceiling.\n- (3) People are meeting in a natural outdoor setting.\n- (4) A large electronic display is visible on the wall of the conference hall.',
#   'img': 'busan_dive.jpg'},
#  {'no': 2,
#   'eng': "Which of the following descriptions of the image is incorrect?\n- (1) There is a large yellow sculpture in the image.\n- (2) The building is named 'Local Stitch'.\n- (3) The exterior walls of the building are painted blue.\n- (4) There are several windows visible on the building.",
#   'img': 'local_stitch.jpg'},
#  {'no': 3,
#   'eng': 'Which of the following descriptions of the image is incorrect?\n- (1) The cafe has a yellow wall.\n- (2) Customers are ordering at the counter.\n- (3) Trees are visible outside the windows.\n- (4) All tables have people sitting at them.',
#   'img': 'local_stitch_terrarosa.jpg'},
#  {'no': 4,
#   'eng': 'Which of the following descriptions of the image is incorrect?\n- (1) A coffee shop is located on the first floor of the building.\n- (2) The building is made of red bricks.\n- (3) The traffic light at the intersection shows green.\n- (4) There is an orange cone placed on the road in front of the building.',
#   'img': 'mangwon.jpg'},
#  {'no': 5,
#   'eng': 'Which of the following descriptions of the image is incorrect?\n- (1) Various types of bread are displayed.\n- (2) Two clerks wearing caps are visible.\n- (3) All the bread prices are the same.\n- (4) The display is divided into two levels.',
#   'img': 'mangwon_bakery.jpg'},
#  {'no': 6,
#   'eng': 'Which of the following descriptions of the image is incorrect?\n- (1) People are working outside the building.\n- (2) There are red chairs stacked in the middle.\n- (3) One of the workers is wearing a white helmet.\n- (4) On the right, you can see a sign with "뉴트리코어" (Nutricore).',
#   'img': 'sangam_interior.jpg'},
#  {'no': 7,
#   'eng': 'Which of the following descriptions of the image is incorrect?\n- (1) Natural light is coming through large windows.\n- (2) People are studying individually at tables.\n- (3) There are several chairs arranged in what appears to be a dining area.\n- (4) The floor is finished with dark wood.',
#   'img': 'seolleung_terrarosa.jpg'},
#  {'no': 8,
#   'eng': 'Which of the following descriptions of the image is incorrect?\n- (1) People are queuing to board a bus.\n- (2) The window of the café has the words "COFFEE & BAKERY" on it.\n- (3) Trees are lined up next to the station.\n- (4) Everyone is wearing black clothes.',
#   'img': 'stanford_coffee.jpg'}]

# %%
voices = ['alloy', 'ash', 'coral', 'echo', 'fable', 'onyx', 'nova', 'sage' , 'shimmer']
# 목소리 주인 이름

for q in eng_dict:
    no = q['no']
    quiz = q['eng']
    quiz = quiz.replace("- (1)", "- One.\t")
    quiz = quiz.replace("- (2)", "- Two.\t")
    quiz = quiz.replace("- (3)", "- Three.\t")
    quiz = quiz.replace("- (4)", "- Four.\t")    

    print(no, quiz)
    
    voice = voices[no % len(voices)] # 문제 개수를 목소리 개수로 나눈 나머지 값으로 선택  

    response = client.audio.speech.create(
        model="tts-1-hd",
        voice=voice,
        input=f'#{no}. {quiz}',
    )

    response.write_to_file(f"../data/audio/{no}.mp3")
# Out:
# 1 Which of the following descriptions of the image is incorrect?
# - One.	 Many people are using laptops in a conference space.
# - Two.	 There are several lights installed on the ceiling.
# - Three.	 People are meeting in a natural outdoor setting.
# - Four.	 A large electronic display is visible on the wall of the conference hall.
# 2 Which of the following descriptions of the image is incorrect?
# - One.	 There is a large yellow sculpture in the image.
# - Two.	 The building is named 'Local Stitch'.
# - Three.	 The exterior walls of the building are painted blue.
# - Four.	 There are several windows visible on the building.
# 3 Which of the following descriptions of the image is incorrect?
# - One.	 The cafe has a yellow wall.
# - Two.	 Customers are ordering at the counter.
# - Three.	 Trees are visible outside the windows.
# - Four.	 All tables have people sitting at them.
# 4 Which of the following descriptions of the image is incorrect?
# - One.	 A coffee shop is located on the first floor of the building.
# - Two.	 The building is made of red bricks.
# - Three.	 The traffic light at the intersection shows green.
# - Four.	 There is an orange cone placed on the road in front of the building.
# 5 Which of the following descriptions of the image is incorrect?
# - One.	 Various types of bread are displayed.
# - Two.	 Two clerks wearing caps are visible.
# - Three.	 All the bread prices are the same.
# - Four.	 The display is divided into two levels.
# 6 Which of the following descriptions of the image is incorrect?
# - One.	 People are working outside the building.
# - Two.	 There are red chairs stacked in the middle.
# - Three.	 One of the workers is wearing a white helmet.
# - Four.	 On the right, you can see a sign with "뉴트리코어" (Nutricore).
# 7 Which of the following descriptions of the image is incorrect?
# - One.	 Natural light is coming through large windows.
# - Two.	 People are studying individually at tables.
# - Three.	 There are several chairs arranged in what appears to be a dining area.
# - Four.	 The floor is finished with dark wood.
# 8 Which of the following descriptions of the image is incorrect?
# - One.	 People are queuing to board a bus.
# - Two.	 The window of the café has the words "COFFEE & BAKERY" on it.
# - Three.	 Trees are lined up next to the station.
# - Four.	 Everyone is wearing black clothes.

# %%
ipd.Audio(f"../data/audio/1.mp3")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
